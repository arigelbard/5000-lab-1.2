# %% [markdown]
# ---
# title: "Pets"
# author: "Ari Gelbard"
# format:
#     revealjs:
#         code-fold: true
# bibliography: ../reference.bib
# ---

# %% [markdown]
# ## Norman
# ![My cat norman](images/norman.jpg)
#
# Random source:  [@brandsaas2024partial]

# %% [markdown]
# ## Chart
#
# Here is a chart: <details>
#
# ```{python}
# #| code-fold: show
# import matplotlib.pyplot as plt
#
# x = [10, 20, 30, 40]
# y = [1, 2, 3, 4]
#
# plt.plot(x,y)
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt 

x = [10, 20, 30, 40]
y = [1, 2, 3, 4]

plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Sage
# ![My cat sage](images/sage.jpg)

# %% [markdown]
# ## References
